# %% [markdown]
# Rueben Varghese Philip 21BAI1817 Assignment 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# Load the dataset

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/House Price India.csv')
df1
# Out:
#                id   Date  number_of_bedrooms  number_of_bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living_area  lot_area  number_of_floors  waterfront_present  \
# 0             3650      9050               2.0                   0
# ...

# %%
X=df1.iloc[:100,:-1] #reshaped the rows upto 100 rows, previously 14620 rows
y=df1.iloc[:100,-1]
print(X)
# Out:
#             id   Date  number_of_bedrooms  number_of_bathrooms  living_area  \
# 0   6762810145  42491                   5                 2.50         3650
# 1   6762810635  42491                   4                 2.50         2920
# 2   6762810998  42491                   5                 2.75         2910
# 3   6762812605  42491                   4                 2.50         3310
# 4   6762812919  42491                   3                 2.00         2710
# ..         ...    ...                 ...                  ...          ...
# 95  6762813766  42494                   4                 1.75         2010
# 96  6762813838  42494                   4                 2.50         3180
# 97  6762814206  42494                   4                 2.50         2450
# 98  6762814291  42494                   3                 2.50         2490
# 99  6762814896  42494                   3                 2.50         1680
#
# ...

# %% [markdown]
# Univariate Analysis

# %%
X.lot_area.plot()
# Out:
# <Axes: >

# %%
X1=df1.iloc[:10,:-1] #reshape 10 columns
X1.plot()
# Out:
# <Axes: >

# %%
sb.distplot(X.number_of_floors)
# Out:
# <ipython-input-25-5acf82ece126>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(X.number_of_floors)
# <Axes: xlabel='number_of_floors', ylabel='Density'>

# %%
X2=df1.iloc[:5,:-1] #reshape 5 columns for piechart
y2=df1.iloc[:5,-1]
plt.pie(X2.number_of_floors,[0,0,0.1,0,0],labels=['t1','t2','t3','t4','t5'],autopct = "%1.1f%%",shadow=True,colors = ['yellow','orange','red','green','blue'])
plt.show()

# %%
plt.bar(X.number_of_bedrooms,X.number_of_bathrooms)
# Out:
# <BarContainer object of 100 artists>

# %%
plt.boxplot(X['number_of_bedrooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cfaa4446a10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7cfaa4446f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7cfaa4446770>],
#  'medians': [<matplotlib.lines.Line2D at 0x7cfaa4447490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7cfaa4447730>],
#  'means': []}

# %% [markdown]
# Bi-variate Analysis

# %%
sb.scatterplot(x='number_of_bathrooms',y='number_of_floors',data=X)
# Out:
# <Axes: xlabel='number_of_bathrooms', ylabel='number_of_floors'>

# %%
sb.barplot(x='number_of_bathrooms',y='number_of_floors',data=X)
# Out:
# <Axes: xlabel='number_of_bathrooms', ylabel='number_of_floors'>

# %%
sb.jointplot(x='number_of_bathrooms',y='number_of_floors',data=X)

# %% [markdown]
# Multivariate analysis

# %%
X3=df1.iloc[:50,:7] #reshape 50 rows, 7 columns
sb.pairplot(X3)

# %%
sb.heatmap(X3.corr(),annot=True,)
# Out:
# <Axes: >

# %% [markdown]
# Descriptive statistics

# %%
df1.describe() #descriptive statistics
# Out:
#                  id          Date  number_of_bedrooms  number_of_bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living_area      lot_area  number_of_floors  waterfront_present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# Handling the missing values

# %%
print(df1.notnull()) #checking missing values
# Out:
#          id  Date  number_of_bedrooms  number_of_bathrooms  living_area  \
# 0      True  True                True                 True         True
# 1      True  True                True                 True         True
# 2      True  True                True                 True         True
# 3      True  True                True                 True         True
# 4      True  True                True                 True         True
# ...     ...   ...                 ...                  ...          ...
# 14615  True  True                True                 True         True
# 14616  True  True                True                 True         True
# 14617  True  True                True                 True         True
# 14618  True  True                True                 True         True
# 14619  True  True                True                 True         True
#
#        lot_area  number_of_floors  waterfront_present  number_of_views  \
# ...
